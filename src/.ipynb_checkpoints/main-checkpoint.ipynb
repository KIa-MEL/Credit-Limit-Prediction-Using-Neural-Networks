# %% [markdown]
# # **Credit Limit** Prediction Using Deep Neural Networks
#
# ## Authors
# - **Kianoosh Vadaei**: Researcher
# - **Melika Shirian**: Researcher
#
# ### Contact Information
# - Kianoosh Vadaei: [email](mailto:kia.vadaei@gmail.com), [LinkedIn](https://www.linkedin.com/in/kianoosh-vadaei-0aa58611b/), [GitHub](https://github.com/kia-vadaei)
# - Melika Shirian: [email](mel.shirian@gmail.com), [LinkedIn](https://www.linkedin.com/in/melika-shirian-b8477a254/), [GitHub](https://github.com/MelikaShirian12)
#
#
# ## Introduction
# This notebook provides an analysis of **Credit Limit** Prediction. We will cover the following steps:
# 1. Data Loading
# 2. Data Preprocessing
# 3. Exploratory Data Analysis
# 4. Model Building
# 5. Model Evaluation
# 6. Conclusion
#
# ## Table of Contents
# 1. [Introduction](#Introduction)
# 2. [Data Loading](#Data-Loading)
# 3. [Data Preprocessing](#Data-Preprocessing)
# 4. [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# 5. [Model Building](#Model-Building)
# 6. [Model Evaluation](#Model-Evaluation)
# 7. [Conclusion](#Conclusion)

# %%
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau, MultiplicativeLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import *
import time
from dataset import Dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# <a id='Data-Loading'></a>
# ## **Data Loading**
# In this section, we will load the dataset and display the first few rows to understand its structure.

# %%
dataset = Dataset(data_path='../data/CreditPrediction.csv', target_col='Credit_Limit')
dataset.load_data()
dataset.preprocess_data(features_score_plot=True)
dataset.X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[196], line 2
#       1 dataset = Dataset(data_path='../data/CreditPrediction.csv', target_col='Credit_Limit')
# ----> 2 dataset.load_data()
#       3 dataset.preprocess_data(features_score_plot=True)
#       4 dataset.X_train.shape
#
# File ~/Desktop/uni/projects/ML-P1/DeepLearning_Regression_BankSet/src/dataset.py:30, in Dataset.load_data(self)
#      29 def load_data(self):
# ---> 30     self.data_df = pd.read_csv(self.data_path)
#      31     return None
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## **Done Outliers:**

# %%
# print(data_no_dup['Credit_Limit'].skew())
# print(data_no_dup.shape)
# sns.histplot(data=data_no_dup,x="Credit_Limit")
# plt.show()

# upper=data_no_dup['Credit_Limit'].quantile(0.25)
# lower=data_no_dup['Credit_Limit'].quantile(0.75)

# #print(upper,lower)

# index=data_no_dup[(data_no_dup['Credit_Limit']>=lower)|(data_no_dup['Credit_Limit']<=upper)].index

# data_no_dup.drop(index,inplace=True)
# print(data_no_dup.shape)

# data_no_dup['Credit_Limit'].describe()
# print(data_no_dup['Credit_Limit'].skew())
# plt.boxplot(data_no_dup['Credit_Limit'], vert=False)
# plt.title("Boxplot of the sample after treating the outliers")
# plt.xlabel("Sample")

# data_no_dup.shape

# %%
class Model(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Model, self).__init__()
        self.dropout = nn.Dropout(0.2)
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.leaky_reLu = nn.LeakyReLU()
        self.reLu = nn.ReLU()

        self.linear2 = nn.Linear(hidden_size, 1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        out = self.dropout(x)

        out = self.linear1(out)
        out = self.leaky_reLu(out)
        out = self.linear2(out)
        # out = self.sigmoid(out)
        return out

# %%
class Model2(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Model2, self).__init__()
        self.dropout = nn.Dropout(0.05)
        self.linear1 = nn.Linear(input_size, hidden_size)

        
        self.linear2 = nn.Linear(hidden_size, int(hidden_size/2))
        self.linear3 = nn.Linear(int(hidden_size/2), 1)
        # self.linear4 = nn.Linear(12, 1)


        self.leaky_reLu = nn.LeakyReLU()
        self.reLu = nn.ReLU()

        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        out = self.dropout(x)
        out = self.linear1(out)
        out = self.leaky_reLu(out)
        out = self.linear2(out)
        out = self.leaky_reLu(out)
        out = self.linear3(out)
        # out = self.leaky_reLu(out)
        # out = self.linear4(out)
        # out = self.sigmoid(out)
        return out

# %%
model = Model2(n_features , 16)
model = model.to(device)

n_features
# Out:
# 17

# %%
num_epochs = 300000
learning_rate = 0.001
list_of_losses = []
list_of_losses_test = []
criterion = nn.MSELoss()  ####################################################################
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
lmbda = lambda epoch: 0.95

scheduler = MultiplicativeLR(optimizer, lr_lambda=lmbda)
lambda_reg = 0.01
loss = 0



for epoch in range(num_epochs):
    # Forward pass and loss
    # model.zero_grad()
    y_pred = model(X_train_fs)
    loss = criterion(y_pred, y_train)

    # TODO Validation
    # TODO Bath
    # TODO 2 for

    # # Compute L2 regularization term
    l2_reg = torch.tensor(0.)
    l2_reg = l2_reg.to(device)

    for param in model.parameters():
        l2_reg += torch.norm(param)
    
    # Add regularization term to loss
    loss += lambda_reg * l2_reg

    # Backward pass and update

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    # zero grad before new step

    if (epoch+1) % 1000 == 0:
        print(f"epoch: {epoch+1}, loss = {loss.item():.4f} || "
              f"lr: {optimizer.state_dict()['param_groups'][0]['lr']:.7f}")
        list_of_losses.append(loss.item())
        list_of_losses_test.append(criterion(model(X_test_fs), y_test).item())
    if (epoch+1) % 5000 == 0 and epoch > 5000:
        scheduler.step()
# Out:
# epoch: 1000, loss = 22174840.0000 || lr: 0.0010000
# epoch: 2000, loss = 4259591.0000 || lr: 0.0010000
# epoch: 3000, loss = 2735504.5000 || lr: 0.0010000
# epoch: 4000, loss = 2214036.2500 || lr: 0.0010000
# epoch: 5000, loss = 2048006.3750 || lr: 0.0010000
# epoch: 6000, loss = 1969606.1250 || lr: 0.0010000
# epoch: 7000, loss = 1910231.0000 || lr: 0.0010000
# epoch: 8000, loss = 1853508.5000 || lr: 0.0010000
# epoch: 9000, loss = 1792601.7500 || lr: 0.0010000
# epoch: 10000, loss = 1815797.6250 || lr: 0.0010000
# epoch: 11000, loss = 1734546.1250 || lr: 0.0009500
# epoch: 12000, loss = 1799167.2500 || lr: 0.0009500
# epoch: 13000, loss = 1787035.3750 || lr: 0.0009500
# epoch: 14000, loss = 1728229.2500 || lr: 0.0009500
# epoch: 15000, loss = 1831070.7500 || lr: 0.0009500
# epoch: 16000, loss = 1805065.2500 || lr: 0.0009025
# epoch: 17000, loss = 1748842.3750 || lr: 0.0009025
# epoch: 18000, loss = 1719577.2500 || lr: 0.0009025
# epoch: 19000, loss = 1677587.2500 || lr: 0.0009025
# epoch: 20000, loss = 1718461.5000 || lr: 0.0009025
# epoch: 21000, loss = 1732084.3750 || lr: 0.0008574
# epoch: 22000, loss = 1769350.5000 || lr: 0.0008574
# epoch: 23000, loss = 1768110.7500 || lr: 0.0008574
# epoch: 24000, loss = 1754237.2500 || lr: 0.0008574
# epoch: 25000, loss = 1777338.1250 || lr: 0.0008574
# epoch: 26000, loss = 1810276.7500 || lr: 0.0008145
# epoch: 27000, loss = 1741937.5000 || lr: 0.0008145
# epoch: 28000, loss = 1676534.8750 || lr: 0.0008145
# epoch: 82000, loss = 1703735.8750 || lr: 0.0004633
# epoch: 83000, loss = 1729049.7500 || lr: 0.0004633
# epoch: 84000, loss = 1736149.0000 || lr: 0.0004633
# epoch: 85000, loss = 1858838.5000 || lr: 0.0004633
# epoch: 86000, loss = 1752024.3750 || lr: 0.0004401
# epoch: 87000, loss = 1743032.7500 || lr: 0.0004401
# epoch: 88000, loss = 1730602.5000 || lr: 0.0004401
# epoch: 89000, loss = 1729292.0000 || lr: 0.0004401
# epoch: 90000, loss = 1680616.3750 || lr: 0.0004401
# epoch: 91000, loss = 1744999.6250 || lr: 0.0004181
# epoch: 92000, loss = 1745654.2500 || lr: 0.0004181
# epoch: 93000, loss = 1724285.8750 || lr: 0.0004181
# epoch: 94000, loss = 1756352.7500 || lr: 0.0004181
# epoch: 95000, loss = 1744223.2500 || lr: 0.0004181
# epoch: 96000, loss = 1758936.1250 || lr: 0.0003972
# epoch: 97000, loss = 1696749.2500 || lr: 0.0003972
# epoch: 98000, loss = 1766683.8750 || lr: 0.0003972
# epoch: 99000, loss = 1772228.1250 || lr: 0.0003972
# epoch: 100000, loss = 1730736.2500 || lr: 0.0003972
# epoch: 101000, loss = 1732846.7500 || lr: 0.0003774
# epoch: 102000, loss = 1768734.2500 || lr: 0.0003774
# epoch: 103000, loss = 1736716.8750 || lr: 0.0003774
# epoch: 104000, loss = 1656060.8750 || lr: 0.0003774
# epoch: 105000, loss = 1721259.5000 || lr: 0.0003774
# epoch: 106000, loss = 1744112.1250 || lr: 0.0003585
# epoch: 107000, loss = 1763572.8750 || lr: 0.0003585
# epoch: 108000, loss = 1691445.3750 || lr: 0.0003585
# epoch: 109000, loss = 1735069.7500 || lr: 0.0003585
# epoch: 110000, loss = 1693562.8750 || lr: 0.0003585
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 30
#      27 l2_reg = l2_reg.to(device)
#      29 for param in model.parameters():
# ---> 30     l2_reg += torch.norm(param)
#      32 # Add regularization term to loss
#      33 loss += lambda_reg * l2_reg
#
# KeyboardInterrupt:

# %%
epochs = [epoch * 1000 for epoch in range(1, len(list_of_losses) + 1)]

# Plot the losses
plt.plot(epochs, list_of_losses, linestyle='-', color='b', label='Training Loss')
plt.plot(epochs, list_of_losses_test, linestyle='-', color='r', label='Testing Loss')

# Add title and labels
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch (multiplied by 1000)')
plt.ylabel('Loss')

# Add grid
plt.grid(True)

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
from sklearn.metrics import mean_squared_error
with torch.no_grad():
    y_predicted = model(X_test_fs)
    # y_predicted = np.array(y_predicted)
     
    MSE = mean_squared_error(y_predicted.cpu(), y_test.cpu())
MSE
# Out:
# 1796105.4

# %%
#random forest
X_train_fs = X_test_fs.to('cpu')
y_train = y_test.to('cpu')
X_test_fs = X_test_fs.to('cpu')
y_test = y_test.to('cpu')


X_test_fs = X_test_fs.numpy()
X_train_fs = X_train_fs.numpy()
y_test = y_test.numpy().flatten()
y_train = y_train.numpy().flatten()

# %%
y_train.shape
# Out:
# (1671,)

# %%
# Import libraries
import pandas as pd
from pycaret.regression import *
s = setup(data = X_train_fs, target = y_train, session_id=123)
best = compare_models()
evaluate_model(best)
predict_holdout = predict_model(X_test_fs)
# Out:
# <style type="text/css">
# #T_91798_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T
13_col6, #T_f858a_row14_col0, #T_f858a_row14_col1, #T_f858a_row14_col2, #T_f858a_row14_col3, #T_f858a_row14_col4, #T_f858a_row14_col5, #T_f858a_row14_col6, #T_f858a_row15_col0, #T_f858a_row15_col1, #T_f858a_row15_col2, #T_f858a_row15_col3, #T_f858a_row15_col4, #T_f858a_row15_col5, #T_f858a_row15_col6, #T_f858a_row16_col0, #T_f858a_row16_col1, #T_f858a_row16_col2, #T_f858a_row16_col3, #T_f858a_row16_col4, #T_f858a_row16_col5, #T_f858a_row16_col6, #T_f858a_row17_col0, #T_f858a_row17_col1, #T_f858a_row17_col2, #T_f858a_row17_col3, #T_f858a_row17_col4, #T_f858a_row17_col5, #T_f858a_row17_col6 {
#   text-align: left;
# }
# #T_f858a_row0_col4, #T_f858a_row1_col1, #T_f858a_row1_col2, #T_f858a_row1_col3, #T_f858a_row3_col5, #T_f858a_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f858a_row0_col7, #T_f858a_row1_col7, #T_f858a_row2_col7, #T_f858a_row3_col7, #T_f858a_row4_col7, #T_f858a_row5_col7, #T_f858a_row6_col7, #T_f858a_row7_col7, #T_f858a_row8_col7, #T_f858a_row9_col7, #T_f858a_row10_col7, #T_f858a_row11_col7, #T_f858a_row12_col7, #T_f858a_row13_col7, #T_f858a_row14_col7, #T_f858a_row15_col7, #T_f858a_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f858a_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f858a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f858a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f858a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f858a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f858a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f858a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f858a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f858a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f858a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f858a_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_f858a_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f858a_row0_col1" class="data row0 col1" >991.2974</td>
#       <td id="T_f858a_row0_col2" class="data row0 col2" >1909855.8374</td>
#       <td id="T_f858a_row0_col3" class="data row0 col3" >1374.4037</td>
#       <td id="T_f858a_row0_col4" class="data row0 col4" >0.6436</td>
#       <td id="T_f858a_row0_col5" class="data row0 col5" >0.2404</td>
#       <td id="T_f858a_row0_col6" class="data row0 col6" >0.1923</td>
#       <td id="T_f858a_row0_col7" class="data row0 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_f858a_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_f858a_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f858a_row1_col1" class="data row1 col1" >923.0064</td>
#       <td id="T_f858a_row1_col2" class="data row1 col2" >1905038.6010</td>
#       <td id="T_f858a_row1_col3" class="data row1 col3" >1372.2331</td>
#       <td id="T_f858a_row1_col4" class="data row1 col4" >0.6435</td>
#       <td id="T_f858a_row1_col5" class="data row1 col5" >0.2391</td>
#       <td id="T_f858a_row1_col6" class="data row1 col6" >0.1765</td>
#       <td id="T_f858a_row1_col7" class="data row1 col7" >1.6200</td>
#     </tr>
#     <tr>
#       <th id="T_f858a_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_f858a_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_f858a_row2_col1" class="data row2 col1" >952.4820</td>
#       <td id="T_f858a_row2_col2" class="data row2 col2" >1963189.5281</td>
#       <td id="T_f858a_row2_col3" class="data row2 col3" >1392.0056</td>
#       <td id="T_f858a_row2_col4" class="data row2 col4" >0.6340</td>
#       <td id="T_f858a_row2_col5" class="data row2 col5" >0.2369</td>
#       <td id="T_f858a_row2_col6" class="data row2 col6" >0.1764</td>
#       <td id="T_f858a_row2_col7" class="data row2 col7" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_f858a_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_f858a_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_f858a_row3_col1" class="data row3 col1" >944.4852</td>
#       <td id="T_f858a_row3_col2" class="data row3 col2" >1965715.6232</td>
#       <td id="T_f858a_row3_col3" class="data row3 col3" >1392.5279</td>
#       <td id="T_f858a_row3_col4" class="data row3 col4" >0.6338</td>
#       <td id="T_f858a_row3_col5" class="data row3 col5" >0.2364</td>
#       <td id="T_f858a_row3_col6" class="data row3 col6" >0.1753</td>
#       <td id="T_f858a_row3_col7" class="data row3 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_f858a_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_f858a_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_f858a_row4_col1" class="data row4 col1" >1094.4852</td>
#       <td id="T_f858a_row4_col2" class="data row4 col2" >1970381.7750</td>
#       <td id="T_f858a_row4_col3" class="data row4 col3" >1398.6728</td>
#       <td id="T_f858a_row4_col4" class="data row4 col4" >0.6302</td>
#       <td id="T_f858a_row4_col5" class="data row4 col5" >0.3035</td>
#       <td id="T_f858a_row4_col6" class="data row4 col6" >0.2291</td>
#       <td id="T_f858a_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_f858a_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_f858a_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_f858a_row5_col1" class="data row5 col1" >1094.6931</td>
#       <td id="T_f858a_row5_col2" class="data row5 col2" >1970184.8875</td>
#       <td id="T_f858a_row5_col3" class="data row5 col3" >1398.5815</td>
#       <td id="T_f858a_row5_col4" class="data row5 col4" >0.6302</td>
#       <td id="T_f858a_row5_col5" class="data row5 col5" >0.3043</td>
#       <td id="T_f858a_row5_col6" class="data row5 col6" >0.2292</td>
#       <td id="T_f858a_row5_col7" class="data row5 col7
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 7
#       5 best = compare_models()
#       6 evaluate_model(best)
# ----> 7 predict_holdout = predict_model(X_test_fs)
#
# File ~/anaconda3/envs/pytorch/lib/python3.11/site-packages/pycaret/regression/functional.py:1895, in predict_model(estimator, data, round, verbose)
#    1892 if experiment is None:
#    1893     experiment = _EXPERIMENT_CLASS()
# -> 1895 return experiment.predict_model(
#    1896     estimator=estimator,
#    1897     data=data,
#    1898     round=round,
#    1899     verbose=verbose,
#    1900 )
#
# File ~/anaconda3/envs/pytorch/lib/python3.11/site-packages/pycaret/regression/oop.py:2188, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2134 def predict_model(
#    2135     self,
#    2136     estimator,
#    (...)
#    2139     verbose: bool = True,
#    2140 ) -> pd.DataFrame:
#    2141     """
#    2142     This function predicts ``Label`` using a trained model. When ``data`` is
#    2143     None, it predicts label on the holdout set.
#    (...)
#    2185
#    2186     """
# -> 2188     return super().predict_model(
#    2189         estimator=estimator,
#    2190         data=data,
#    2191         probability_threshold=None,
#    2192         encoded_labels=False,
#    2193         round=round,
#    2194         verbose=verbose,
#    2195     )
#
# File ~/anaconda3/envs/pytorch/lib/python3.11/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:4992, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4989         probability_threshold = estimator.probability_threshold
#    4990     estimator = get_estimator_from_meta_estimator(estimator)
# -> 4992 pred = np.nan_to_num(estimator.predict(X_test_))
#    4993 pred = pipeline.inverse_transform(pred)
#    4994 # Need to convert labels back to numbers
#    4995 # TODO optimize
#
# AttributeError: 'numpy.ndarray' object has no attribute 'predict'
